# %%
# !pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import folium

# %%
# !pip install geocoder
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 KB 3.8 MB/s eta 0:00:00
# ...

# %%
import geocoder

# %%
city = "台北市"
city_1 = geocoder.osm(city).latlng
city_gps = [25.036042, 121.562338]
city_gps1 = [25.032771, 121.563372]
city_gps2 = [25.033243, 121.558716]
city_gps3 = [25.034532, 121.557630]
city_gps4 = [25.040810097606254, 121.57539135800295]
city_gps5 = [25.049275648788935, 121.57850840135826]
city_gps6 = [25.033181373353155, 121.5686582659718]
city_gps7 = [25.037654971743553, 121.55564536440319]
city_gps8 = [25.041514007333216, 121.5574585376986]
city_gps9 = [25.037936870172306, 121.56129946100343]
city_gps10 = [25.03778220211026, 121.55289822000285]
city_gps11 = [25.042974750933897, 121.56770292135536]
city_gps12 = [25.044240633342522, 121.56387963824527]
city_gps13 = [25.03650951782222, 121.56985884614183]

MRT =[25.033117, 121.562760]
MRT2 =[25.041206478757477, 121.57670173535371]
MRT3 = [25.033475373015627, 121.57021080546545]
MRT4 = [25.04258336228508, 121.55756447478043]
MRT5 = [25.04126140049969, 121.56649086637445]
MRT7 = [25.050724952024932, 121.57767182081508]

m = folium.Map(location=city_1, zoom_start=14,tiles='Stamen Terrain')
folium.Marker(location=city_gps, popup='市民廣場',icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps1, popup='捷運台北101/世貿站', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps2, popup='信義基隆路口', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps3, popup='三張犁', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps4, popup='永春', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps5, popup='松山', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps6, popup='象山', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps7, popup='仁愛延吉街口', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps8, popup='捷運國父紀念館站', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps9, popup='仁愛逸仙路口', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps10, popup='仁愛安和路口', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps11, popup='捷運市政府站(3號出口)', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps12, popup='松山高中', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)
folium.Marker(location=city_gps13, popup='興雅國中', icon=folium.Icon(icon='fa-bicycle',color='green',prefix='fa')).add_to(m)

folium.Marker(location=MRT, popup='台北101/世貿', icon=folium.Icon(icon='fa-train',color='blue',prefix='fa'),tiles='Stamen Terrain').add_to(m)
folium.Marker(location=MRT3, popup='象山', icon=folium.Icon(icon='fa-train',color='blue',prefix='fa'),tiles='Stamen Terrain').add_to(m)
folium.Marker(location=MRT4, popup='國父紀念館', icon=folium.Icon(icon='fa-train',color='blue',prefix='fa'),tiles='Stamen Terrain').add_to(m)
folium.Marker(location=MRT5, popup='市政府', icon=folium.Icon(icon='fa-train',color='blue',prefix='fa'),tiles='Stamen Terrain').add_to(m)
folium.Marker(location=MRT2, popup='永春', icon=folium.Icon(icon='fa-train',color='blue',prefix='fa'),tiles='Stamen Terrain').add_to(m)
folium.Marker(location=MRT7, popup='象山', icon=folium.Icon(icon='fa-train',color='blue',prefix='fa'),tiles='Stamen Terrain').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
